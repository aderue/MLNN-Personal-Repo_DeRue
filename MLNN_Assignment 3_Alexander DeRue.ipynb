# %% [markdown]
# # Assigment 3
# This assigment focuses on getting comfortable with working with multidimensional data and linear regression.
# Key items include:
# - Creating random n-dimensional data
# - Creating a Model that can handle the data
# - Plot a subset of the data along with the prediction
# - Using a Dataset to read in and choose certain columns to produce a model
# - Create several models from various combinations of columns
# - Plot a few of the results
# - BONUS: Perform all the plots in 3D instead of 2D

# %% [markdown]
# # ALEXANDER DERUE MLNN ASSIGNMENT #3

# %% [markdown]
# ## 1. Create a 4 dimensional data set with 64 elements and show 2D plots of the data $x_1 \rightarrow y, x_2 \rightarrow y$, etc.

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
n = 64
x = np.linspace(0, 1, n) + np.random.rand(4, n)
x = np.vstack([x, np.ones(len(x.T))]).T
x
# Out:
# array([[0.19139755, 0.973205  , 0.36144064, 0.43535039, 1.        ],
#        [0.17499756, 0.77554743, 0.7726202 , 0.44345818, 1.        ],
#        [0.46343028, 1.02459646, 0.82226638, 0.27463509, 1.        ],
#        [0.10875068, 0.44754624, 0.54636887, 0.66301426, 1.        ],
#        [0.40036413, 0.47877662, 0.8647733 , 0.42959189, 1.        ],
#        [0.8672385 , 0.8637076 , 0.40853302, 0.29815741, 1.        ],
#        [0.89340718, 1.05103752, 0.92569708, 0.40221665, 1.        ],
#        [0.19642261, 0.70165852, 1.04936977, 0.67789126, 1.        ],
#        [0.16354177, 0.62316668, 0.81675084, 0.20679925, 1.        ],
#        [0.18826613, 0.35689989, 0.85620769, 0.24340643, 1.        ],
#        [0.32905741, 1.08614073, 0.95478827, 0.26051735, 1.        ],
#        [0.38807034, 0.59825722, 0.57081521, 0.29949385, 1.        ],
#        [0.4814054 , 0.74789558, 0.97253976, 0.45304125, 1.        ],
#        [0.56951818, 0.35818584, 0.4697018 , 0.30439307, 1.        ],
# ...

# %%
y = np.linspace(0, 100, n) + np.random.rand(n) - .3
y
# Out:
# array([-0.16678053,  1.58142572,  3.28704417,  4.90913251,  6.70812215,
#         8.12600241,  9.98333155, 11.24564197, 13.22643945, 14.66944824,
#        16.5612203 , 17.88826316, 19.32181691, 20.94069896, 22.0816183 ,
#        23.57541707, 25.76341535, 27.47754868, 28.44410644, 29.90594771,
#        32.38369549, 33.2681953 , 34.8776335 , 37.16016919, 38.51533997,
#        40.09488624, 41.96363317, 43.27778595, 45.07749787, 46.19209604,
#        48.26173718, 49.6995855 , 50.69535638, 52.21646014, 54.05512441,
#        56.20907758, 56.94680783, 58.95781485, 60.80816155, 61.65062655,
#        63.83583288, 64.87554565, 66.50020855, 68.68626184, 69.81159442,
#        71.60151885, 73.16476457, 75.2443964 , 76.21422345, 77.97691439,
#        80.02602885, 81.39313687, 82.44918995, 84.0751461 , 86.23949974,
#        87.27069994, 89.52333971, 90.72308146, 91.92326719, 94.15577627,
#        95.04850277, 97.44843075, 98.89014382, 99.75966936])

# %%
plt.scatter(x.T[0], y)

# %%
plt.scatter(x.T[1], y)

# %%
plt.scatter(x.T[2], y)

# %%
plt.scatter(x.T[3], y)

# %% [markdown]
# ## 2.  Create a model to fit the data. Hint: follow the example from Lesson 3

# %%
beta = np.linalg.lstsq(x, y)[0]
beta
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# array([ 18.24016407,  25.33913522,  19.52730263,  18.74818898,
#        -32.94924557])

# %%
pred = np.dot(x, beta)

# %% [markdown]
# ## 3. Plot the model's prediction in 2D for 2 of the dimensions ($x_1 \rightarrow y_p, x_2 \rightarrow y_p$) along with the original points

# %%
plt.scatter(x.T[0], pred, c ='green')
plt.scatter(x.T[0], y, c='y')

# %% [markdown]
# ## 4. Read in `mlnn/data/Credit.csv` with Pandas and create a model to predict Credit Rating (`Rating`). Use only the numeric columns in your model, but feel free to experiment which which columns you believe are better predicters of Credit Rating

# %%
import pandas as pd
credit = pd.read_csv('../data/Credit.csv')
credit.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %%
X = credit[['Income', 'Limit', 'Cards', 'Age', 'Balance']].as_matrix()

X = np.vstack([X.T, np.ones(len(X))]).T
X
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[1.48910e+01, 3.60600e+03, 2.00000e+00, 3.40000e+01, 3.33000e+02,
#         1.00000e+00],
#        [1.06025e+02, 6.64500e+03, 3.00000e+00, 8.20000e+01, 9.03000e+02,
#         1.00000e+00],
#        [1.04593e+02, 7.07500e+03, 4.00000e+00, 7.10000e+01, 5.80000e+02,
#         1.00000e+00],
#        ...,
#        [5.78720e+01, 4.17100e+03, 5.00000e+00, 6.70000e+01, 1.38000e+02,
#         1.00000e+00],
#        [3.77280e+01, 2.52500e+03, 1.00000e+00, 4.40000e+01, 0.00000e+00,
#         1.00000e+00],
#        [1.87010e+01, 5.52400e+03, 5.00000e+00, 6.40000e+01, 9.66000e+02,
#         1.00000e+00]])

# %%
y = credit['Rating']
y.head(5)
# Out:
# 0    283
# 1    483
# 2    514
# 3    681
# 4    357
# Name: Rating, dtype: int64

# %% [markdown]
# ### 5. Plot your results (Bonus if you use 3D plots). Show as many of your columns vs. credit rating that you can.

# %%
#quick guide [0] income [1] limit [2] cards [3] age [4] balance
plt.scatter(X.T[0], y)

# %%
plt.scatter(X.T[0], y)

# %%
plt.scatter(X.T[2], y)

# %% [markdown]
# This seemed to develop a fairly normal distribution, barring for the inability for one's number of credit cards to be negative.

# %%
plt.scatter(X.T[3], y)

# %%
plt.scatter(X.T[4], y)

# %%
betacred = np.linalg.lstsq(X, y)[0]
betacred
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# array([9.44521575e-02, 6.42652445e-02, 4.70733430e+00, 7.47835535e-03,
#        8.04840384e-03, 2.78109538e+01])

# %%
predcred = np.dot(X, betacred)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30,240)
ax.scatter(X.T[0], X.T[1], predcred, zdir='z', c='y')
ax.scatter(X.T[0], X.T[1], y, zdir='z', c='green')

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30,240)
ax.scatter(X.T[3], X.T[4], predcred, zdir='z', c='y')
ax.scatter(X.T[3], X.T[4], y, zdir='z', c='green')

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30,180)
ax.scatter(X.T[3], X.T[4], predcred, zdir='z', c='y')
ax.scatter(X.T[3], X.T[4], y, zdir='z', c='green')

# %% [markdown]
# It's interesting to see how little effect age has given the role of the length of one's credit history on credit rating. As expected income and credit limit are strong predictors.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30,70)
ax.scatter(X.T[0], X.T[4], predcred, zdir='z', c='y')
ax.scatter(X.T[0], X.T[4], y, zdir='z', c='green')

# %% [markdown]
# Presuming my understanding of balance is correct - being the average amount a person owes month to month -  I'm suprised it's a positive predictor of credit.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(-30,20)
ax.scatter(X.T[0], X.T[2], predcred, zdir='z', c='y')
ax.scatter(X.T[0], X.T[2], y, zdir='z', c='green')

# %% [markdown]
# I'm still impressed by the bell-ish curve based on the number of cards a person has. I had hypothesized a negative relationship with credit rating, but both credit novices and experts have a single card, where a far greater number appear to have a 2-4 cards and low - moderate credit.
